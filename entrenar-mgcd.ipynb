# %%
import os
#

# %%
# License: BSD
# Based on : Sasank Chilamkurthy
# Modificado 20211210

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

EPOCHS=200

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(degrees=30),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]), 'test': transforms.Compose([
        transforms.RandomRotation(degrees=300),
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# Set clasificado 
data_dir = '/home/pablo/MEGA/pub/ITBA/ECD/tpfinal/mgcd/MGCD'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x])
                  for x in ['train', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4, shuffle=True, num_workers=2)
              for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
class_names = image_datasets['train'].classes

## Torch Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

# MGCD
# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Train

# %%
def train_model(model, dataldr, criterion, optimizer, scheduler, num_epochs=EPOCHS):
    since = time.time()

    best_acc = 0.0
    vals_train_loss = []
    vals_test_loss = []
    vals_train_acc = []
    vals_test_acc = []
    epoch_times = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    for epoch in range(num_epochs):
        since_epoch = time.time()
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataldr[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            if phase == 'train':
                vals_train_loss.append(epoch_loss)
                vals_train_acc.append(epoch_acc)
            else:
                vals_test_loss.append(epoch_loss)
                vals_test_acc.append(epoch_acc)
            
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        epoch_elapsed = time.time() - since_epoch
        epoch_times.append(epoch_elapsed)
        print('Epoch complete in {:.0f}m {:.0f}s'.format(epoch_elapsed // 60, epoch_elapsed % 60))
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, vals_train_loss, vals_test_loss, vals_train_acc, vals_test_acc

def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
modelo = models.resnet18(pretrained=True)
num_ftrs = modelo.fc.in_features
modelo.fc = nn.Linear(num_ftrs, len(class_names))

modelo = modelo.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(modelo.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
train_losess = []
test_losess = []
train_accuracy = []
test_accuracy = []
model_ft, train_losses, test_losses, train_accuracy, test_accuracy = train_model(modelo, dataloaders, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=EPOCHS)
# Out:
# Epoch 0/199
# ----------
# train Loss: 1.0817 Acc: 0.6358
# test Loss: 1.3042 Acc: 0.6102
# Epoch complete in 0m 51s
#
# Epoch 1/199
# ----------
# train Loss: 0.7423 Acc: 0.7582
# test Loss: 1.2170 Acc: 0.6825
# Epoch complete in 1m 7s
#
# Epoch 2/199
# ----------
# train Loss: 0.5847 Acc: 0.8083
# test Loss: 1.4081 Acc: 0.6747
# Epoch complete in 1m 8s
#
# Epoch 3/199
# ----------
# train Loss: 0.5382 Acc: 0.8217
# test Loss: 1.3049 Acc: 0.6575
# Epoch complete in 1m 7s
#
# Epoch 4/199
# ----------
# train Loss: 0.4394 Acc: 0.8518
# test Loss: 0.9742 Acc: 0.7600
# Epoch complete in 1m 7s
#
# Epoch 5/199
# ----------
# train Loss: 0.4348 Acc: 0.8588
# test Loss: 1.0612 Acc: 0.7350
# Epoch complete in 1m 6s
#
# Epoch 6/199
# ----------
# train Loss: 0.4116 Acc: 0.8640
# test Loss: 1.4067 Acc: 0.7045
# Epoch complete in 1m 5s
#
# Epoch 7/199
# ----------
# train Loss: 0.2494 Acc: 0.9180
# test Loss: 1.0063 Acc: 0.7420
# Epoch complete in 1m 4s
#
# Epoch 8/199
# ----------
# train Loss: 0.2264 Acc: 0.9263
# test Loss: 1.0282 Acc: 0.7448
# Epoch complete in 1m 7s
#
# Epoch 9/199
# ----------
# train Loss: 0.2341 Acc: 0.9307
# test Loss: 0.9806 Acc: 0.7442
# Epoch complete in 1m 4s
#
# Epoch 10/199
# ----------
# train Loss: 0.1882 Acc: 0.9410
# test Loss: 0.9974 Acc: 0.7450
# Epoch complete in 0m 41s
#
# Epoch 11/199
# ----------
# train Loss: 0.1852 Acc: 0.9443
# test Loss: 1.0469 Acc: 0.7455
# Epoch complete in 0m 42s
#
# Epoch 12/199
# ----------
# train Loss: 0.1806 Acc: 0.9420
# test Loss: 1.0859 Acc: 0.7365
# Epoch complete in 1m 8s
#
# Epoch 13/199
# ----------
# train Loss: 0.1975 Acc: 0.9370
# test Loss: 0.9860 Acc: 0.7662
# Epoch complete in 1m 9s
#
# Epoch 14/199
# ----------
# train Loss: 0.1751 Acc: 0.9440
# test Loss: 0.9746 Acc: 0.7628
# Epoch complete in 1m 9s
#
# Epoch 15/199
# ----------
# train Loss: 0.1820 Acc: 0.9400
# test Loss: 0.9532 Acc: 0.7610
# Epoch complete in 1m 8s
#
# Epoch 16/199
# ----------
# train Loss: 0.1663 Acc: 0.9507
# test Loss: 1.0192 Acc: 0.7458
# Epoch complete in 1m 8s
#
# Epoch 17/199
# ----------
# train Loss: 0.1625 Acc: 0.9527
# test Loss: 1.0274 Acc: 0.7542
# Epoch complete in 1m 7s
#
# Epoch 18/199
# ----------
# train Loss: 0.1589 Acc: 0.9473
# test Loss: 1.0192 Acc: 0.7452
# Epoch complete in 1m 5s
#
# Epoch 19/199
# ----------
# train Loss: 0.1948 Acc: 0.9387
# test Loss: 0.8482 Acc: 0.7750
# Epoch complete in 1m 5s
#
# Epoch 20/199
# ----------
# train Loss: 0.1926 Acc: 0.9463
# test Loss: 1.0337 Acc: 0.7542
# Epoch complete in 1m 6s
#
# Epoch 21/199
# ----------
# train Loss: 0.1914 Acc: 0.9423
# test Loss: 1.0134 Acc: 0.7492
# Epoch complete in 1m 5s
#
# Epoch 22/199
# ----------
# train Loss: 0.1785 Acc: 0.9497
# test Loss: 0.8757 Acc: 0.7722
# Epoch complete in 0m 41s
#
# Epoch 23/199
# ----------
# train Loss: 0.1724 Acc: 0.9487
# test Loss: 1.1077 Acc: 0.7430
# Epoch complete in 0m 40s
#
# Epoch 24/199
# ----------
# train Loss: 0.1669 Acc: 0.9480
# test Loss: 0.8846 Acc: 0.7650
# Epoch complete in 0m 40s
#
# Epoch 25/199
# ----------
# train Loss: 0.1840 Acc: 0.9430
# test Loss: 1.0245 Acc: 0.7505
# Epoch complete in 0m 40s
#
# Epoch 26/199
# ----------
# train Loss: 0.1809 Acc: 0.9443
# test Loss: 0.9743 Acc: 0.7665
# Epoch complete in 0m 40s
#
# Epoch 27/199
# ----------
# train Loss: 0.1600 Acc: 0.9533
# test Loss: 1.0112 Acc: 0.7582
# Epoch complete in 0m 41s
#
# Epoch 28/199
# ----------
# train Loss: 0.1765 Acc: 0.9435
# test Loss: 1.0267 Acc: 0.7350
# Epoch complete in 0m 40s
#
# Epoch 29/199
# ----------
# train Loss: 0.1664 Acc: 0.9463
# test Loss: 1.1359 Acc: 0.7280
# Epoch complete in 0m 40s
#
# Epoch 30/199
# ----------
# train Loss: 0.1589 Acc: 0.9485
# test Loss: 0.9834 Acc: 0.7600
# Epoch complete in 0m 40s
#
# Epoch 31/199
# ----------
# train Loss: 0.1845 Acc: 0.9390
# test Loss: 0.9434 Acc: 0.7692
# Epoch complete in 0m 40s
#
# Epoch 32/199
# ----------
# train Loss: 0.1934 Acc: 0.9457
# test Loss: 0.9533 Acc: 0.7675
# Epoch complete in 0m 40s
#
# Epoch 33/199
# ----------
# train Loss: 0.1670 Acc: 0.9547
# test Loss: 1.0119 Acc: 0.7438
# Epoch complete in 0m 40s
#
# Epoch 34/199
# ----------
# train Loss: 0.1685 Acc: 0.9477
# test Loss: 1.0645 Acc: 0.7400
# Epoch complete in 0m 40s
#
# Epoch 35/199
# ----------
# train Loss: 0.1652 Acc: 0.9450
# test Loss: 0.9403 Acc: 0.7608
# Epoch complete in 0m 40s
#
# Epoch 36/199
# ----------
# train Loss: 0.1809 Acc: 0.9490
# test Loss: 1.0089 Acc: 0.7642
# Epoch complete in 0m 40s
#
# Epoch 37/199
# ----------
# train Loss: 0.1869 Acc: 0.9425
# test Loss: 1.0063 Acc: 0.7488
# Epoch complete in 0m 40s
#
# Epoch 38/199
# ----------
# train Loss: 0.1799 Acc: 0.9393
# test Loss: 0.9756 Acc: 0.7560
# Epoch complete in 0m 41s
#
# Epoch 39/199
# ----------
# train Loss: 0.1780 Acc: 0.9480
# test Loss: 1.0521 Acc: 0.7555
# Epoch complete in 0m 41s
#
# Epoch 40/199
# ----------
# train Loss: 0.1699 Acc: 0.9470
# test Loss: 0.9643 Acc: 0.7540
# Epoch complete in 1m 9s
#
# Epoch 41/199
# ----------
# train Loss: 0.1765 Acc: 0.9457
# test Loss: 0.9603 Acc: 0.7660
# Epoch complete in 1m 9s
#
# Epoch 42/199
# ----------
# train Loss: 0.1956 Acc: 0.9410
# test Loss: 1.0646 Acc: 0.7472
# Epoch complete in 1m 9s
#
# Epoch 43/199
# ----------
# train Loss: 0.1893 Acc: 0.9393
# test Loss: 0.9706 Acc: 0.7595
# Epoch complete in 1m 8s
#
# Epoch 44/199
# ----------
# train Loss: 0.1926 Acc: 0.9387
# test Loss: 1.0663 Acc: 0.7492
# Epoch complete in 1m 9s
#
# Epoch 45/199
# ----------
# train Loss: 0.1856 Acc: 0.9463
# test Loss: 1.0596 Acc: 0.7438
# Epoch complete in 1m 9s
#
# Epoch 46/199
# ----------
# train Loss: 0.1814 Acc: 0.9483
# test Loss: 0.9730 Acc: 0.7645
# Epoch complete in 1m 9s
#
# Epoch 47/199
# ----------
# train Loss: 0.1694 Acc: 0.9455
# test Loss: 1.0247 Acc: 0.7505
# Epoch complete in 1m 8s
#
# Epoch 48/199
# ----------
# train Loss: 0.1611 Acc: 0.9495
# test Loss: 1.0657 Acc: 0.7452
# Epoch complete in 1m 9s
#
# Epoch 49/199
# ----------
# train Loss: 0.1868 Acc: 0.9385
# test Loss: 0.9230 Acc: 0.7682
# Epoch complete in 1m 8s
#
# Epoch 50/199
# ----------
# train Loss: 0.1593 Acc: 0.9503
# test Loss: 1.0744 Acc: 0.7385
# Epoch complete in 0m 41s
#
# Epoch 51/199
# ----------
# train Loss: 0.1634 Acc: 0.9477
# test Loss: 1.0369 Acc: 0.7502
# Epoch complete in 1m 8s
#
# Epoch 52/199
# ----------
# train Loss: 0.1658 Acc: 0.9505
# test Loss: 1.0288 Acc: 0.7480
# Epoch complete in 1m 9s
#
# Epoch 53/199
# ----------
# train Loss: 0.1712 Acc: 0.9495
# test Loss: 0.8877 Acc: 0.7698
# Epoch complete in 1m 8s
#
# Epoch 54/199
# ----------
# train Loss: 0.1772 Acc: 0.9473
# test Loss: 1.0608 Acc: 0.7408
# Epoch complete in 1m 9s
#
# Epoch 55/199
# ----------
# train Loss: 0.1660 Acc: 0.9473
# test Loss: 0.8751 Acc: 0.7870
# Epoch complete in 1m 8s
#
# Epoch 56/199
# ----------
# train Loss: 0.1900 Acc: 0.9410
# test Loss: 0.9471 Acc: 0.7525
# Epoch complete in 1m 6s
#
# Epoch 57/199
# ----------
# train Loss: 0.1695 Acc: 0.9480
# test Loss: 1.0967 Acc: 0.7395
# Epoch complete in 1m 7s
#
# Epoch 58/199
# ----------
# train Loss: 0.1762 Acc: 0.9435
# test Loss: 1.0064 Acc: 0.7540
# Epoch complete in 1m 7s
#
# Epoch 59/199
# ----------
# train Loss: 0.1703 Acc: 0.9477
# test Loss: 1.0520 Acc: 0.7455
# Epoch complete in 1m 9s
#
# Epoch 60/199
# ----------
# train Loss: 0.1903 Acc: 0.9433
# test Loss: 1.0873 Acc: 0.7430
# Epoch complete in 1m 9s
#
# Epoch 61/199
# ----------
# train Loss: 0.1821 Acc: 0.9390
# test Loss: 1.0241 Acc: 0.7372
# Epoch complete in 0m 41s
#
# Epoch 62/199
# ----------
# train Loss: 0.1548 Acc: 0.9533
# test Loss: 0.9158 Acc: 0.7715
# Epoch complete in 0m 41s
#
# Epoch 63/199
# ----------
# train Loss: 0.1717 Acc: 0.9460
# test Loss: 1.0443 Acc: 0.7435
# Epoch complete in 0m 41s
#
# Epoch 64/199
# ----------
# train Loss: 0.1681 Acc: 0.9477
# test Loss: 0.9779 Acc: 0.7442
# Epoch complete in 0m 50s
#
# Epoch 65/199
# ----------
# train Loss: 0.1663 Acc: 0.9505
# test Loss: 1.0147 Acc: 0.7508
# Epoch complete in 0m 48s
#
# Epoch 66/199
# ----------
# train Loss: 0.1674 Acc: 0.9490
# test Loss: 1.0679 Acc: 0.7458
# Epoch complete in 0m 41s
#
# Epoch 67/199
# ----------
# train Loss: 0.1904 Acc: 0.9447
# test Loss: 1.0476 Acc: 0.7530
# Epoch complete in 0m 41s
#
# Epoch 68/199
# ----------
# train Loss: 0.1867 Acc: 0.9420
# test Loss: 0.9537 Acc: 0.7638
# Epoch complete in 0m 44s
#
# Epoch 69/199
# ----------
# train Loss: 0.1716 Acc: 0.9477
# test Loss: 0.9796 Acc: 0.7680
# Epoch complete in 1m 6s
#
# Epoch 70/199
# ----------
# train Loss: 0.1652 Acc: 0.9487
# test Loss: 1.0446 Acc: 0.7338
# Epoch complete in 1m 6s
#
# Epoch 71/199
# ----------
# train Loss: 0.1862 Acc: 0.9455
# test Loss: 0.9365 Acc: 0.7610
# Epoch complete in 1m 7s
#
# Epoch 72/199
# ----------
# train Loss: 0.1567 Acc: 0.9500
# test Loss: 0.9519 Acc: 0.7600
# Epoch complete in 1m 9s
#
# Epoch 73/199
# ----------
# train Loss: 0.1927 Acc: 0.9425
# test Loss: 1.0345 Acc: 0.7372
# Epoch complete in 1m 9s
#
# Epoch 74/199
# ----------
# train Loss: 0.1770 Acc: 0.9453
# test Loss: 1.0962 Acc: 0.7470
# Epoch complete in 1m 8s
#
# Epoch 75/199
# ----------
# train Loss: 0.1828 Acc: 0.9450
# test Loss: 1.1342 Acc: 0.7295
# Epoch complete in 1m 8s
#
# Epoch 76/199
# ----------
# train Loss: 0.1706 Acc: 0.9473
# test Loss: 1.0561 Acc: 0.7528
# Epoch complete in 1m 9s
#
# Epoch 77/199
# ----------
# train Loss: 0.1987 Acc: 0.9410
# test Loss: 0.9186 Acc: 0.7740
# Epoch complete in 1m 7s
#
# Epoch 78/199
# ----------
# train Loss: 0.1744 Acc: 0.9437
# test Loss: 1.0159 Acc: 0.7478
# Epoch complete in 1m 9s
#
# Epoch 79/199
# ----------
# train Loss: 0.1577 Acc: 0.9517
# test Loss: 0.9594 Acc: 0.7530
# Epoch complete in 1m 8s
#
# Epoch 80/199
# ----------
# train Loss: 0.1640 Acc: 0.9473
# test Loss: 0.9536 Acc: 0.7680
# Epoch complete in 1m 8s
#
# Epoch 81/199
# ----------
# train Loss: 0.1699 Acc: 0.9447
# test Loss: 1.0693 Acc: 0.7425
# Epoch complete in 1m 8s
#
# Epoch 82/199
# ----------
# train Loss: 0.1732 Acc: 0.9475
# test Loss: 0.9512 Acc: 0.7572
# Epoch complete in 1m 8s
#
# Epoch 83/199
# ----------
# train Loss: 0.1877 Acc: 0.9440
# test Loss: 0.9881 Acc: 0.7600
# Epoch complete in 1m 10s
#
# Epoch 84/199
# ----------
# train Loss: 0.1821 Acc: 0.9440
# test Loss: 1.1120 Acc: 0.7412
# Epoch complete in 1m 11s
#
# Epoch 85/199
# ----------
# train Loss: 0.1732 Acc: 0.9437
# test Loss: 0.9330 Acc: 0.7652
# Epoch complete in 1m 11s
#
# Epoch 86/199
# ----------
# train Loss: 0.1782 Acc: 0.9447
# test Loss: 1.0547 Acc: 0.7368
# Epoch complete in 1m 11s
#
# Epoch 87/199
# ----------
# train Loss: 0.1892 Acc: 0.9400
# test Loss: 0.9761 Acc: 0.7618
# Epoch complete in 1m 12s
#
# Epoch 88/199
# ----------
# train Loss: 0.1552 Acc: 0.9537
# test Loss: 0.9570 Acc: 0.7552
# Epoch complete in 1m 11s
#
# Epoch 89/199
# ----------
# train Loss: 0.1687 Acc: 0.9453
# test Loss: 0.9026 Acc: 0.7708
# Epoch complete in 1m 12s
#
# Epoch 90/199
# ----------
# train Loss: 0.1981 Acc: 0.9377
# test Loss: 1.0091 Acc: 0.7580
# Epoch complete in 1m 11s
#
# Epoch 91/199
# ----------
# train Loss: 0.1790 Acc: 0.9427
# test Loss: 1.0219 Acc: 0.7508
# Epoch complete in 1m 10s
#
# Epoch 92/199
# ----------
# train Loss: 0.1608 Acc: 0.9497
# test Loss: 0.9975 Acc: 0.7552
# Epoch complete in 1m 9s
#
# Epoch 93/199
# ----------
# train Loss: 0.1947 Acc: 0.9443
# test Loss: 0.9966 Acc: 0.7568
# Epoch complete in 1m 8s
#
# Epoch 94/199
# ----------
# train Loss: 0.1652 Acc: 0.9467
# test Loss: 0.9280 Acc: 0.7712
# Epoch complete in 1m 8s
#
# Epoch 95/199
# ----------
# train Loss: 0.1554 Acc: 0.9487
# test Loss: 1.0041 Acc: 0.7612
# Epoch complete in 1m 8s
#
# Epoch 96/199
# ----------
# train Loss: 0.1593 Acc: 0.9510
# test Loss: 0.9228 Acc: 0.7690
# Epoch complete in 1m 9s
#
# Epoch 97/199
# ----------
# train Loss: 0.1566 Acc: 0.9503
# test Loss: 0.9355 Acc: 0.7600
# Epoch complete in 1m 8s
#
# Epoch 98/199
# ----------
# train Loss: 0.1545 Acc: 0.9495
# test Loss: 1.0057 Acc: 0.7508
# Epoch complete in 1m 9s
#
# Epoch 99/199
# ----------
# train Loss: 0.1662 Acc: 0.9463
# test Loss: 0.9981 Acc: 0.7448
# Epoch complete in 1m 8s
#
# Epoch 100/199
# ----------
# train Loss: 0.1829 Acc: 0.9467
# test Loss: 0.9946 Acc: 0.7492
# Epoch complete in 1m 9s
#
# Epoch 101/199
# ----------
# train Loss: 0.1594 Acc: 0.9525
# test Loss: 0.9814 Acc: 0.7585
# Epoch complete in 1m 9s
#
# Epoch 102/199
# ----------
# train Loss: 0.1807 Acc: 0.9463
# test Loss: 1.0112 Acc: 0.7472
# Epoch complete in 1m 8s
#
# Epoch 103/199
# ----------
# train Loss: 0.1829 Acc: 0.9427
# test Loss: 1.0923 Acc: 0.7278
# Epoch complete in 1m 8s
#
# Epoch 104/199
# ----------
# train Loss: 0.1833 Acc: 0.9447
# test Loss: 0.9322 Acc: 0.7578
# Epoch complete in 1m 8s
#
# Epoch 105/199
# ----------
# train Loss: 0.1705 Acc: 0.9477
# test Loss: 1.0259 Acc: 0.7418
# Epoch complete in 1m 8s
#
# Epoch 106/199
# ----------
# train Loss: 0.1593 Acc: 0.9537
# test Loss: 1.0314 Acc: 0.7408
# Epoch complete in 1m 5s
#
# Epoch 107/199
# ----------
# train Loss: 0.1625 Acc: 0.9495
# test Loss: 0.9723 Acc: 0.7442
# Epoch complete in 1m 5s
#
# Epoch 108/199
# ----------
# train Loss: 0.1864 Acc: 0.9390
# test Loss: 1.0534 Acc: 0.7388
# Epoch complete in 1m 5s
#
# Epoch 109/199
# ----------
# train Loss: 0.1760 Acc: 0.9520
# test Loss: 1.1332 Acc: 0.7502
# Epoch complete in 1m 4s
#
# Epoch 110/199
# ----------
# train Loss: 0.1753 Acc: 0.9453
# test Loss: 0.9400 Acc: 0.7670
# Epoch complete in 1m 5s
#
# Epoch 111/199
# ----------
# train Loss: 0.1582 Acc: 0.9485
# test Loss: 0.9876 Acc: 0.7470
# Epoch complete in 1m 5s
#
# Epoch 112/199
# ----------
# train Loss: 0.1669 Acc: 0.9473
# test Loss: 0.9941 Acc: 0.7558
# Epoch complete in 1m 5s
#
# Epoch 113/199
# ----------
# train Loss: 0.1763 Acc: 0.9453
# test Loss: 1.0870 Acc: 0.7470
# Epoch complete in 1m 6s
#
# Epoch 114/199
# ----------
# train Loss: 0.1772 Acc: 0.9475
# test Loss: 0.9222 Acc: 0.7580
# Epoch complete in 1m 5s
#
# Epoch 115/199
# ----------
# train Loss: 0.1908 Acc: 0.9393
# test Loss: 1.0152 Acc: 0.7500
# Epoch complete in 1m 5s
#
# Epoch 116/199
# ----------
# train Loss: 0.1737 Acc: 0.9497
# test Loss: 1.0488 Acc: 0.7498
# Epoch complete in 1m 5s
#
# Epoch 117/199
# ----------
# train Loss: 0.1749 Acc: 0.9500
# test Loss: 0.9018 Acc: 0.7642
# Epoch complete in 1m 5s
#
# Epoch 118/199
# ----------
# train Loss: 0.1658 Acc: 0.9463
# test Loss: 1.0128 Acc: 0.7492
# Epoch complete in 1m 5s
#
# Epoch 119/199
# ----------
# train Loss: 0.1719 Acc: 0.9493
# test Loss: 0.9597 Acc: 0.7525
# Epoch complete in 1m 4s
#
# Epoch 120/199
# ----------
# train Loss: 0.1817 Acc: 0.9435
# test Loss: 0.9858 Acc: 0.7470
# Epoch complete in 1m 5s
#
# Epoch 121/199
# ----------
# train Loss: 0.1784 Acc: 0.9423
# test Loss: 1.0976 Acc: 0.7228
# Epoch complete in 1m 5s
#
# Epoch 122/199
# ----------
# train Loss: 0.1864 Acc: 0.9455
# test Loss: 1.0172 Acc: 0.7552
# Epoch complete in 1m 5s
#
# Epoch 123/199
# ----------
# train Loss: 0.1697 Acc: 0.9450
# test Loss: 1.0955 Acc: 0.7408
# Epoch complete in 1m 5s
#
# Epoch 124/199
# ----------
# train Loss: 0.1874 Acc: 0.9450
# test Loss: 1.0081 Acc: 0.7505
# Epoch complete in 1m 5s
#
# Epoch 125/199
# ----------
# train Loss: 0.1737 Acc: 0.9485
# test Loss: 1.0178 Acc: 0.7432
# Epoch complete in 1m 5s
#
# Epoch 126/199
# ----------
# train Loss: 0.1719 Acc: 0.9467
# test Loss: 0.9718 Acc: 0.7578
# Epoch complete in 1m 5s
#
# Epoch 127/199
# ----------
# train Loss: 0.1730 Acc: 0.9447
# test Loss: 0.9807 Acc: 0.7600
# Epoch complete in 1m 5s
#
# Epoch 128/199
# ----------
# train Loss: 0.1586 Acc: 0.9503
# test Loss: 1.0286 Acc: 0.7532
# Epoch complete in 1m 5s
#
# Epoch 129/199
# ----------
# train Loss: 0.1691 Acc: 0.9517
# test Loss: 1.0493 Acc: 0.7362
# Epoch complete in 1m 5s
#
# Epoch 130/199
# ----------
# train Loss: 0.1580 Acc: 0.9523
# test Loss: 0.9833 Acc: 0.7508
# Epoch complete in 1m 5s
#
# Epoch 131/199
# ----------
# train Loss: 0.1658 Acc: 0.9477
# test Loss: 1.0256 Acc: 0.7550
# Epoch complete in 1m 5s
#
# Epoch 132/199
# ----------
# train Loss: 0.1699 Acc: 0.9455
# test Loss: 0.9444 Acc: 0.7530
# Epoch complete in 1m 5s
#
# Epoch 133/199
# ----------
# train Loss: 0.1916 Acc: 0.9435
# test Loss: 0.8863 Acc: 0.7860
# Epoch complete in 1m 4s
#
# Epoch 134/199
# ----------
# train Loss: 0.1683 Acc: 0.9490
# test Loss: 1.0351 Acc: 0.7520
# Epoch complete in 1m 4s
#
# Epoch 135/199
# ----------
# train Loss: 0.1537 Acc: 0.9510
# test Loss: 1.0197 Acc: 0.7482
# Epoch complete in 1m 4s
#
# Epoch 136/199
# ----------
# train Loss: 0.1709 Acc: 0.9517
# test Loss: 1.0316 Acc: 0.7468
# Epoch complete in 1m 3s
#
# Epoch 137/199
# ----------
# train Loss: 0.1946 Acc: 0.9410
# test Loss: 1.0331 Acc: 0.7550
# Epoch complete in 1m 3s
#
# Epoch 138/199
# ----------
# train Loss: 0.1625 Acc: 0.9483
# test Loss: 0.8469 Acc: 0.7830
# Epoch complete in 1m 2s
#
# Epoch 139/199
# ----------
# train Loss: 0.1770 Acc: 0.9480
# test Loss: 0.9778 Acc: 0.7528
# Epoch complete in 1m 1s
#
# Epoch 140/199
# ----------
# train Loss: 0.1631 Acc: 0.9477
# test Loss: 0.9894 Acc: 0.7590
# Epoch complete in 0m 59s
#
# Epoch 141/199
# ----------
# train Loss: 0.1737 Acc: 0.9455
# test Loss: 0.9677 Acc: 0.7532
# Epoch complete in 0m 58s
#
# Epoch 142/199
# ----------
# train Loss: 0.1715 Acc: 0.9480
# test Loss: 0.8633 Acc: 0.7685
# Epoch complete in 0m 57s
#
# Epoch 143/199
# ----------
# train Loss: 0.1730 Acc: 0.9480
# test Loss: 1.2348 Acc: 0.7323
# Epoch complete in 0m 56s
#
# Epoch 144/199
# ----------
# train Loss: 0.1932 Acc: 0.9417
# test Loss: 0.9741 Acc: 0.7628
# Epoch complete in 0m 57s
#
# Epoch 145/199
# ----------
# train Loss: 0.1676 Acc: 0.9480
# test Loss: 0.9305 Acc: 0.7568
# Epoch complete in 0m 56s
#
# Epoch 146/199
# ----------
# train Loss: 0.1751 Acc: 0.9453
# test Loss: 0.9839 Acc: 0.7515
# Epoch complete in 0m 58s
#
# Epoch 147/199
# ----------
# train Loss: 0.1890 Acc: 0.9425
# test Loss: 0.9818 Acc: 0.7562
# Epoch complete in 0m 59s
#
# Epoch 148/199
# ----------
# train Loss: 0.1837 Acc: 0.9460
# test Loss: 0.9841 Acc: 0.7598
# Epoch complete in 1m 0s
#
# Epoch 149/199
# ----------
# train Loss: 0.1635 Acc: 0.9485
# test Loss: 0.9985 Acc: 0.7552
# Epoch complete in 1m 2s
#
# Epoch 150/199
# ----------
# train Loss: 0.1663 Acc: 0.9475
# test Loss: 1.0265 Acc: 0.7380
# Epoch complete in 1m 2s
#
# Epoch 151/199
# ----------
# train Loss: 0.1725 Acc: 0.9450
# test Loss: 0.9962 Acc: 0.7450
# Epoch complete in 1m 2s
#
# Epoch 152/199
# ----------
# train Loss: 0.1582 Acc: 0.9535
# test Loss: 1.1017 Acc: 0.7305
# Epoch complete in 1m 4s
#
# Epoch 153/199
# ----------
# train Loss: 0.1617 Acc: 0.9503
# test Loss: 0.8982 Acc: 0.7632
# Epoch complete in 1m 4s
#
# Epoch 154/199
# ----------
# train Loss: 0.1929 Acc: 0.9387
# test Loss: 0.9890 Acc: 0.7450
# Epoch complete in 1m 4s
#
# Epoch 155/199
# ----------
# train Loss: 0.1720 Acc: 0.9503
# test Loss: 1.0697 Acc: 0.7512
# Epoch complete in 1m 5s
#
# Epoch 156/199
# ----------
# train Loss: 0.1815 Acc: 0.9467
# test Loss: 0.9136 Acc: 0.7578
# Epoch complete in 1m 4s
#
# Epoch 157/199
# ----------
# train Loss: 0.1742 Acc: 0.9487
# test Loss: 0.9389 Acc: 0.7620
# Epoch complete in 1m 5s
#
# Epoch 158/199
# ----------
# train Loss: 0.1718 Acc: 0.9440
# test Loss: 0.9148 Acc: 0.7812
# Epoch complete in 1m 6s
#
# Epoch 159/199
# ----------
# train Loss: 0.1816 Acc: 0.9447
# test Loss: 1.0861 Acc: 0.7425
# Epoch complete in 1m 5s
#
# Epoch 160/199
# ----------
# train Loss: 0.1831 Acc: 0.9460
# test Loss: 0.9000 Acc: 0.7765
# Epoch complete in 1m 5s
#
# Epoch 161/199
# ----------
# train Loss: 0.1707 Acc: 0.9473
# test Loss: 1.1001 Acc: 0.7335
# Epoch complete in 1m 5s
#
# Epoch 162/199
# ----------
# train Loss: 0.1571 Acc: 0.9520
# test Loss: 0.9374 Acc: 0.7740
# Epoch complete in 1m 5s
#
# Epoch 163/199
# ----------
# train Loss: 0.1533 Acc: 0.9527
# test Loss: 0.9487 Acc: 0.7645
# Epoch complete in 1m 5s
#
# Epoch 164/199
# ----------
# train Loss: 0.1629 Acc: 0.9515
# test Loss: 0.9225 Acc: 0.7660
# Epoch complete in 1m 5s
#
# Epoch 165/199
# ----------
# train Loss: 0.1893 Acc: 0.9437
# test Loss: 1.0267 Acc: 0.7472
# Epoch complete in 1m 5s
#
# Epoch 166/199
# ----------
# train Loss: 0.1788 Acc: 0.9435
# test Loss: 1.0407 Acc: 0.7562
# Epoch complete in 1m 6s
#
# Epoch 167/199
# ----------
# train Loss: 0.1556 Acc: 0.9533
# test Loss: 0.9168 Acc: 0.7688
# Epoch complete in 1m 6s
#
# Epoch 168/199
# ----------
# train Loss: 0.1922 Acc: 0.9427
# test Loss: 1.0512 Acc: 0.7283
# Epoch complete in 1m 5s
#
# Epoch 169/199
# ----------
# train Loss: 0.1522 Acc: 0.9550
# test Loss: 0.9657 Acc: 0.7562
# Epoch complete in 1m 5s
#
# Epoch 170/199
# ----------
# train Loss: 0.1784 Acc: 0.9503
# test Loss: 1.1173 Acc: 0.7400
# Epoch complete in 1m 5s
#
# Epoch 171/199
# ----------
# train Loss: 0.1796 Acc: 0.9445
# test Loss: 0.9804 Acc: 0.7548
# Epoch complete in 1m 5s
#
# Epoch 172/199
# ----------
# train Loss: 0.1987 Acc: 0.9450
# test Loss: 1.0779 Acc: 0.7455
# Epoch complete in 1m 5s
#
# Epoch 173/199
# ----------
# train Loss: 0.1809 Acc: 0.9403
# test Loss: 0.9398 Acc: 0.7610
# Epoch complete in 1m 5s
#
# Epoch 174/199
# ----------
# train Loss: 0.1810 Acc: 0.9435
# test Loss: 1.1043 Acc: 0.7408
# Epoch complete in 1m 5s
#
# Epoch 175/199
# ----------
# train Loss: 0.1750 Acc: 0.9440
# test Loss: 1.0477 Acc: 0.7468
# Epoch complete in 1m 5s
#
# Epoch 176/199
# ----------
# train Loss: 0.1647 Acc: 0.9470
# test Loss: 0.9940 Acc: 0.7410
# Epoch complete in 1m 5s
#
# Epoch 177/199
# ----------
# train Loss: 0.1789 Acc: 0.9507
# test Loss: 0.9641 Acc: 0.7530
# Epoch complete in 1m 4s
#
# Epoch 178/199
# ----------
# train Loss: 0.1536 Acc: 0.9485
# test Loss: 0.9729 Acc: 0.7505
# Epoch complete in 1m 5s
#
# Epoch 179/199
# ----------
# train Loss: 0.1700 Acc: 0.9477
# test Loss: 0.9645 Acc: 0.7498
# Epoch complete in 1m 5s
#
# Epoch 180/199
# ----------
# train Loss: 0.1726 Acc: 0.9450
# test Loss: 1.0742 Acc: 0.7442
# Epoch complete in 1m 5s
#
# Epoch 181/199
# ----------
# train Loss: 0.1845 Acc: 0.9425
# test Loss: 0.9415 Acc: 0.7658
# Epoch complete in 1m 5s
#
# Epoch 182/199
# ----------
# train Loss: 0.1842 Acc: 0.9455
# test Loss: 0.9728 Acc: 0.7518
# Epoch complete in 1m 6s
#
# Epoch 183/199
# ----------
# train Loss: 0.1557 Acc: 0.9485
# test Loss: 1.0093 Acc: 0.7510
# Epoch complete in 1m 5s
#
# Epoch 184/199
# ----------
# train Loss: 0.1821 Acc: 0.9400
# test Loss: 1.0541 Acc: 0.7395
# Epoch complete in 1m 5s
#
# Epoch 185/199
# ----------
# train Loss: 0.1602 Acc: 0.9490
# test Loss: 0.9599 Acc: 0.7690
# Epoch complete in 1m 4s
#
# Epoch 186/199
# ----------
# train Loss: 0.1891 Acc: 0.9405
# test Loss: 0.9952 Acc: 0.7572
# Epoch complete in 1m 4s
#
# Epoch 187/199
# ----------
# train Loss: 0.1775 Acc: 0.9413
# test Loss: 1.0208 Acc: 0.7442
# Epoch complete in 1m 2s
#
# Epoch 188/199
# ----------
# train Loss: 0.1759 Acc: 0.9513
# test Loss: 1.0276 Acc: 0.7522
# Epoch complete in 1m 2s
#
# Epoch 189/199
# ----------
# train Loss: 0.1624 Acc: 0.9495
# test Loss: 0.9468 Acc: 0.7618
# Epoch complete in 1m 1s
#
# Epoch 190/199
# ----------
# train Loss: 0.1550 Acc: 0.9503
# test Loss: 0.9144 Acc: 0.7622
# Epoch complete in 0m 60s
#
# Epoch 191/199
# ----------
# train Loss: 0.1622 Acc: 0.9520
# test Loss: 0.9175 Acc: 0.7600
# Epoch complete in 0m 58s
#
# Epoch 192/199
# ----------
# train Loss: 0.1703 Acc: 0.9460
# test Loss: 0.9605 Acc: 0.7590
# Epoch complete in 0m 56s
#
# Epoch 193/199
# ----------
# train Loss: 0.1790 Acc: 0.9477
# test Loss: 1.0364 Acc: 0.7498
# Epoch complete in 0m 56s
#
# Epoch 194/199
# ----------
# train Loss: 0.1762 Acc: 0.9470
# test Loss: 0.9459 Acc: 0.7732
# Epoch complete in 0m 56s
#
# Epoch 195/199
# ----------
# train Loss: 0.1720 Acc: 0.9477
# test Loss: 1.0283 Acc: 0.7502
# Epoch complete in 0m 56s
#
# Epoch 196/199
# ----------
# train Loss: 0.1699 Acc: 0.9490
# test Loss: 0.9640 Acc: 0.7612
# Epoch complete in 0m 56s
#
# Epoch 197/199
# ----------
# train Loss: 0.1698 Acc: 0.9507
# test Loss: 1.0585 Acc: 0.7375
# Epoch complete in 0m 58s
#
# Epoch 198/199
# ----------
# train Loss: 0.1609 Acc: 0.9507
# test Loss: 1.0813 Acc: 0.7365
# Epoch complete in 1m 1s
#
# Epoch 199/199
# ----------
# train Loss: 0.1663 Acc: 0.9485
# test Loss: 0.8948 Acc: 0.7632
# Epoch complete in 1m 2s
#
# Training complete in 206m 4s
# Best val Acc: 0.787000

# %%
visualize_model(modelo)

# %%
plt.figure(figsize=(10,5))
plt.title("Training Loss vs Test Loss")
plt.plot(test_losses,label="Test Loss")
plt.plot(train_losses,label="Train Loss")
plt.xlabel("Iteraciones")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Training Accuracy vs Test Accuracy")
plt.plot(test_accuracy,label="Test Accuracy")
plt.plot(train_accuracy,label="Train Accuracy")
plt.xlabel("Iteraciones")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
#persisto modelo 
#path = '/content/drive/My Drive/savernet/modelos/chkp_modelo_mgcd.pt'
path = 'chkp_modelo_mgcd.pt'
torch.save({
            'train_losses': train_losses, 
            'test_losses': test_losses, 
            'train_accuracy': train_accuracy, 
            'test_accuracy': test_accuracy, 
            'model_ft_state_dict': modelo.state_dict()
            }, path)

# %%
# Matriz de Confusión
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def get_num_correct(preds, labels):
    if torch.cuda.is_available():
        preds = preds.cuda()
        labels = labels.cuda()
    
    return preds.argmax(dim=1).eq(labels).sum().item()

@torch.no_grad()
def get_all_preds(model, loader):
    
    print(len(loader))
    i=0
    all_preds = torch.cuda.FloatTensor([])
    for batch in loader:
        images, labels = batch
        if torch.cuda.is_available():
            images = images.cuda()
            labels = labels.cuda()

        #borrar
        i=i+1
        if ((i % 50) == 0):
            print(i)
        
        preds = model(images)
        all_preds = torch.cat(
            (all_preds, preds)
            ,dim=0
        )
    return all_preds

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    print(type(cm))
    print(type(classes))
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Predicciones MGCD
with torch.no_grad():
    prediction_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=10)
    train_preds = get_all_preds(modelo, prediction_loader)
# Out:
# 400
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400

# %%
# CM
preds_correct = get_num_correct(train_preds, torch.as_tensor(image_datasets['train'].targets))
#preds_correct = get_num_correct(train_preds, image_datasets['train'].targets)
print('Total Correctas:', preds_correct)
print('Accuracy:', preds_correct / len(image_datasets['train']))

cm = confusion_matrix(image_datasets['train'].targets, train_preds.cpu().argmax(dim=1))
print(type(cm))
#cm

plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, class_names)
# Out:
# Total Correctas: 3883
# Accuracy: 0.97075
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'list'>
# Confusion matrix, without normalization
# [[673   0   4   2   0   6   5]
#  [  0 390   1   2   0   0   7]
#  [  3   0 644   1   1   0   1]
#  [  0   0   9 641   0   0   0]
#  [  0   0   0   0 490  10   0]
#  [  3   0   1   0  25 571   0]
#  [ 10   6  10   0   6   4 474]]

# %% [markdown]
# ## F I N
